# %%
import numpy as np

# import subplots function for plotting
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("talk")
import matplotlib
from matplotlib.pyplot import subplots
import matplotlib.pyplot as plt
from matplotlib import cm

# %matplotlib inline

# %%
sigma = 5.67*10**(-8)
epsilon_snow = np.arange(.96,.98,.005)
epsilon_granite = .5
Trock = 25+273.15
Tsnow = 273.15

# %%
Rrock = sigma*Trock**4*epsilon_granite*(1-epsilon_snow)
Rsnow = sigma*Tsnow**4*epsilon_snow
Rtot = Rsnow + Rrock

plt.plot(epsilon_snow,(Rtot/(sigma*epsilon_snow))**(1./4.)-273.15)
ax = plt.axes()
ax.set_xlim(.96,.98)
ax.set_xlabel('$\epsilon_{snow}$')
ax.set_ylabel('$T_{bright}-T_{snow}$ (K)')
ax.set_title('Approximate impact of rock IR reflections')
