# %% [markdown]
# # Offline Turbulence Simulations (SCP 2m)

# %%
# must insert this statement to render the plots within the notebook
# this is specific to the ipython notebook
# %matplotlib inline

## Import statements
# netcdf/numpy/xr
import numpy as np
from datetime import datetime, timedelta
import pandas as pd
import xarray as xr
import scipy.io as sio

# OS interaction
import sys, pickle, os

# import subplots function for plotting
import seaborn as sns
sns.set_context('talk')
sns.set_style('whitegrid')
import matplotlib
from matplotlib.pyplot import subplots
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.basemap import Basemap
import matplotlib.gridspec as gridspec

import turbpy

# %%
# Project directory
dir_proj = '/Users/karllapo/proj/SnowHydro_OfflineTurb'
dir_print = os.path.join(dir_proj, 'graphics')

# Data
dir_data = os.path.join(dir_proj, 'data')
dir_snq = os.path.join(dir_data, 'SNQ')
dir_scp = os.path.join(dir_data, 'SCP')

# Model output
dir_model_ouptut = os.path.join(dir_data, 'results')

# %% [markdown]
# ## Get SCP observations

# %%
## Read the formatted supporting snoqualmie obs
os.chdir(dir_scp)
Mtower = xr.open_dataset('SCP.Mtower_pottemps.nc')
fluxObs_30m = xr.open_dataset('SCP.flux_obs_30m.netcdf')

# %%
## Met variables
scalarGroundSnowFraction  = 1.
soilRelHumidity = 1.

# Turbulence parameters
z0Ground = .005

# %%
stab_titles = ['Standard',
               'Louis (b = 4.7)',
               'Louis (b = 12)',
               'Louis (Ri capped, MJ98)',
               'Mahrt',
               'MO (Holtslag/de Bruin)',
               'MO (Holtslag/de Bruin - capped)',
               'MO (Beljaars/Holtslag)',
               'MO (Webb - NoahMP)',
               'MO (Cheng/Brutsaert)',
              ]

# Titles for output and xarray datasets
out_titles = {'Standard': 'standard',
              'Louis (b = 4.7)': 'louis',
              'Louis (b = 12)': 'louis_mod',
              'Louis (Ri capped, MJ98)': 'louis_cap',
              'Mahrt': 'mahrt', 
              'MO (Holtslag/de Bruin)': 'HD88',
              'MO (Holtslag/de Bruin - capped)': 'HD88_cap',
              'MO (Beljaars/Holtslag)': 'BJ91',
              'MO (Webb - NoahMP)': 'webb_noah',
              'MO (Cheng/Brutsaert)': 'CB05',
             }

stab_methods = {'Standard': 'standard',
                'Louis (b = 4.7)': 'louis',
                'Louis (b = 12)': 'louis',
                'Louis (Ri capped, MJ98)': 'louis',
                'Mahrt': 'mahrt',
                'MO (Holtslag/de Bruin)': 'monin_obukhov',
                'MO (Holtslag/de Bruin - capped)': 'monin_obukhov',
                'MO (Beljaars/Holtslag)': 'monin_obukhov',
                'MO (Webb - NoahMP)': 'monin_obukhov',
                'MO (Cheng/Brutsaert)': 'monin_obukhov',
               }

gradient_funcs = {'MO (Holtslag/de Bruin)': 'holtslag_debruin',
                  'MO (Holtslag/de Bruin - capped)': 'holtslag_debruin',
                  'MO (Beljaars/Holtslag)': 'beljaar_holtslag',
                  'MO (Beljaars/Holtslag - capped)': 'beljaar_holtslag',
                  'MO (Cheng/Brutsaert)': 'cheng_brutsaert',
                  'MO (Webb - NoahMP)': 'webb_noahmp',
                 }

params = {'Louis (b = 4.7)': 9.4,
          'Louis (Ri capped, MJ98)': 9.4,
          'Louis (b = 12)': 24.}

capping = {'Louis (Ri capped, MJ98)': 'louis_Ri_capping',
           'MO (Holtslag/de Bruin - capped)': 'windless_exchange',
          }

# Initialize the multi-level parameter dictionary
stab_dict = {}
stab_dict['stability_params'] = {}

for st in stab_methods:
    stab_dict[st] = {}
    
    # Assigning the stability method
    stab_dict[st]['stability_method'] = stab_methods[st]
    
    # Assigning the gradient method
    if 'monin_obukhov' in stab_methods[st]:
        stab_dict[st]['monin_obukhov'] = {}
        stab_dict[st]['monin_obukhov']['gradient_function'] = gradient_funcs[st]
        stab_dict[st]['monin_obukhov']['roughness_function'] = 'constant_z0'
        
    # Assiging the capping behavior
    if st in capping.keys():
        stab_dict[st]['capping'] = capping[st]
    
    # Determine stability params
    if st in params.keys():
        stab_dict[st]['stability_params'] = {stab_methods[st]: params[st]}
z0Ground = 0.0005

# %% [markdown]
# ## Discriminate data
#
# Only simulate periods that are stable according to the bulk Richardson number at each height.

# %%
# Select stable conditions only for offline comparison
ri = turbpy.bulkRichardson(Mtower['theta_10m'] + 273.15, Mtower['Tsfc'] + 273.15, Mtower['UBar_10m'], 10.)
Mtower['RiBulk_10m'] = (('time'), ri)
ind_10m = np.nonzero((Mtower.RiBulk_10m > 0.).values)

ri = turbpy.bulkRichardson(Mtower['theta_2m'] + 273.15, Mtower['Tsfc'] + 273.15, Mtower['UBar_2m'], 2.)
Mtower['RiBulk_2m'] = (('time'), ri)
ind_2m = np.nonzero((Mtower.RiBulk_2m > 0.).values)

# %%
offLineCalcFlag = True  # Flag that toggles offline simulation, if False loads previous simulation results

if offLineCalcFlag:     
    sensible_2m = xr.Dataset()
    sensible_2m.coords['time'] = Mtower.time[ind_2m]
    
    print('-------------------------------------')
    print('Shallow Cold Pool -- 2m Simulation   ')
    print('-------------------------------------')
    print(' ')
    mHeight = 2.

    for stab in stab_titles:
        print(stab)

        senHeatGround = np.ones(Mtower.time[ind_2m].size) * np.nan

        # Loop over each time step with snow
        for n, d in enumerate(Mtower.time[ind_2m]):
            if (d['time.hour'].values == 0) & (d['time.minute'].values == 2):
                print(stab + ": " +
                      str(d['time.month'].values) + "/" +
                      str(d['time.day'].values) + "/" +
                      str(d['time.year'].values) +
                      " (" + str(int(n / Mtower.time[ind_2m].size * 100.)) + "%)")
            
            # Met data at Snoqualmie on the given date
            ds = Mtower.sel(time=d)
            snowDepth = 0.  # (m)
            theta_2m = ds.theta_2m + 273.15  # (C) -> (K)
            svp, _ = turbpy.conversionTools.satVapPress(theta_2m)  # Saturation vapor pressure
            airVaporPress = svp * ds.RH_1m_M / 100.  # Vapor pressure (Pa)
            windspd = ds.UBar_2m  # (m/s)

            # Surface variables
            sfcTemp = ds.Tsfc + 273.15  # (C) -> (K)
            sfcVaporPress, _ = turbpy.conversionTools.satVapPress(sfcTemp)

            # 1m
            if np.any(np.isnan([snowDepth, theta_2m,
                                sfcTemp, airVaporPress,
                                sfcVaporPress, windspd])):
                continue
            else:
                # Offline Turbulence Package
                (_, _, senHeatGround[n], 
                 _, _, _) = turbpy.turbFluxes(theta_2m, 101000,
                                              airVaporPress, windspd, sfcTemp,
                                              sfcVaporPress, snowDepth,
                                              mHeight, param_dict=stab_dict[stab],
                                              z0Ground=z0Ground)
        
        out_name = out_titles[stab]
        sensible_2m[out_name] = (('time'), senHeatGround)

    ########
    # Save sensible/latent offline
    os.chdir(dir_model_ouptut)
    sensible_2m.to_netcdf('TF.SCP.sensible_2m_revision.constant_small_z0.nc')
# Out:
# -------------------------------------
# Shallow Cold Pool -- 2m Simulation
# -------------------------------------
#
# Standard
# Standard: 9/24/2012 (2%)
# Standard: 10/8/2012 (5%)
# Standard: 10/9/2012 (7%)
# Standard: 10/10/2012 (9%)
# Standard: 10/11/2012 (10%)
# Standard: 10/12/2012 (12%)
# Standard: 10/13/2012 (13%)
# Standard: 10/14/2012 (15%)
# Standard: 10/15/2012 (16%)
# Standard: 10/16/2012 (18%)
# Standard: 10/17/2012 (20%)
# Standard: 10/18/2012 (21%)
# Standard: 10/19/2012 (23%)
# Standard: 10/20/2012 (25%)
# Standard: 10/21/2012 (27%)
# Standard: 10/22/2012 (29%)
# Standard: 10/23/2012 (30%)
# Standard: 10/24/2012 (32%)
# Standard: 10/27/2012 (34%)
# Standard: 10/28/2012 (34%)
# Standard: 10/29/2012 (35%)
# Standard: 10/30/2012 (37%)
# Standard: 10/31/2012 (39%)
# Standard: 11/1/2012 (41%)
# Standard: 11/2/2012 (43%)
# Standard: 11/3/2012 (45%)
# Standard: 11/4/2012 (47%)
# Standard: 11/5/2012 (49%)
# Standard: 11/6/2012 (51%)
# Standard: 11/7/2012 (53%)
# Standard: 11/8/2012 (55%)
# Standard: 11/9/2012 (57%)
# Standard: 11/10/2012 (59%)
# Standard: 11/12/2012 (62%)
# Standard: 11/13/2012 (64%)
# Standard: 11/14/2012 (66%)
# Standard: 11/15/2012 (68%)
# Standard: 11/16/2012 (69%)
# Standard: 11/17/2012 (71%)
# Standard: 11/18/2012 (73%)
# Standard: 11/19/2012 (75%)
# Standard: 11/20/2012 (77%)
# Standard: 11/21/2012 (79%)
# Standard: 11/22/2012 (81%)
# Standard: 11/23/2012 (83%)
# Standard: 11/24/2012 (85%)
# Standard: 11/25/2012 (88%)
# Standard: 11/26/2012 (90%)
# Standard: 11/28/2012 (93%)
# Standard: 11/29/2012 (95%)
# Standard: 11/30/2012 (97%)
# Louis (b = 4.7)
# Louis (b = 4.7): 9/24/2012 (2%)
# Louis (b = 4.7): 10/8/2012 (5%)
# Louis (b = 4.7): 10/9/2012 (7%)
# Louis (b = 4.7): 10/10/2012 (9%)
# Louis (b = 4.7): 10/11/2012 (10%)
# Louis (b = 4.7): 10/12/2012 (12%)
# Louis (b = 4.7): 10/13/2012 (13%)
# Louis (b = 4.7): 10/14/2012 (15%)
# Louis (b = 4.7): 10/15/2012 (16%)
# Louis (b = 4.7): 10/16/2012 (18%)
# Louis (b = 4.7): 10/17/2012 (20%)
# Louis (b = 4.7): 10/18/2012 (21%)
# Louis (b = 4.7): 10/19/2012 (23%)
# Louis (b = 4.7): 10/20/2012 (25%)
# Louis (b = 4.7): 10/21/2012 (27%)
# Louis (b = 4.7): 10/22/2012 (29%)
# Louis (b = 4.7): 10/23/2012 (30%)
# Louis (b = 4.7): 10/24/2012 (32%)
# Louis (b = 4.7): 10/27/2012 (34%)
# Louis (b = 4.7): 10/28/2012 (34%)
# Louis (b = 4.7): 10/29/2012 (35%)
# Louis (b = 4.7): 10/30/2012 (37%)
# Louis (b = 4.7): 10/31/2012 (39%)
# Louis (b = 4.7): 11/1/2012 (41%)
# Louis (b = 4.7): 11/2/2012 (43%)
# Louis (b = 4.7): 11/3/2012 (45%)
# Louis (b = 4.7): 11/4/2012 (47%)
# Louis (b = 4.7): 11/5/2012 (49%)
# Louis (b = 4.7): 11/6/2012 (51%)
# Louis (b = 4.7): 11/7/2012 (53%)
# Louis (b = 4.7): 11/8/2012 (55%)
# Louis (b = 4.7): 11/9/2012 (57%)
# Louis (b = 4.7): 11/10/2012 (59%)
# Louis (b = 4.7): 11/12/2012 (62%)
# Louis (b = 4.7): 11/13/2012 (64%)
# Louis (b = 4.7): 11/14/2012 (66%)
# Louis (b = 4.7): 11/15/2012 (68%)
# Louis (b = 4.7): 11/16/2012 (69%)
# Louis (b = 4.7): 11/17/2012 (71%)
# Louis (b = 4.7): 11/18/2012 (73%)
# Louis (b = 4.7): 11/19/2012 (75%)
# Louis (b = 4.7): 11/20/2012 (77%)
# Louis (b = 4.7): 11/21/2012 (79%)
# Louis (b = 4.7): 11/22/2012 (81%)
# Louis (b = 4.7): 11/23/2012 (83%)
# Louis (b = 4.7): 11/24/2012 (85%)
# Louis (b = 4.7): 11/25/2012 (88%)
# Louis (b = 4.7): 11/26/2012 (90%)
# Louis (b = 4.7): 11/28/2012 (93%)
# Louis (b = 4.7): 11/29/2012 (95%)
# Louis (b = 4.7): 11/30/2012 (97%)
# Louis (b = 12)
# Louis (b = 12): 9/24/2012 (2%)
# Louis (b = 12): 10/8/2012 (5%)
# Louis (b = 12): 10/9/2012 (7%)
# Louis (b = 12): 10/10/2012 (9%)
# Louis (b = 12): 10/11/2012 (10%)
# Louis (b = 12): 10/12/2012 (12%)
# Louis (b = 12): 10/13/2012 (13%)
# Louis (b = 12): 10/14/2012 (15%)
# Louis (b = 12): 10/15/2012 (16%)
# Louis (b = 12): 10/16/2012 (18%)
# Louis (b = 12): 10/17/2012 (20%)
# Louis (b = 12): 10/18/2012 (21%)
# Louis (b = 12): 10/19/2012 (23%)
# Louis (b = 12): 10/20/2012 (25%)
# Louis (b = 12): 10/21/2012 (27%)
# Louis (b = 12): 10/22/2012 (29%)
# Louis (b = 12): 10/23/2012 (30%)
# Louis (b = 12): 10/24/2012 (32%)
# Louis (b = 12): 10/27/2012 (34%)
# Louis (b = 12): 10/28/2012 (34%)
# Louis (b = 12): 10/29/2012 (35%)
# Louis (b = 12): 10/30/2012 (37%)
# Louis (b = 12): 10/31/2012 (39%)
# Louis (b = 12): 11/1/2012 (41%)
# Louis (b = 12): 11/2/2012 (43%)
# Louis (b = 12): 11/3/2012 (45%)
# Louis (b = 12): 11/4/2012 (47%)
# Louis (b = 12): 11/5/2012 (49%)
# Louis (b = 12): 11/6/2012 (51%)
# Louis (b = 12): 11/7/2012 (53%)
# Louis (b = 12): 11/8/2012 (55%)
# Louis (b = 12): 11/9/2012 (57%)
# Louis (b = 12): 11/10/2012 (59%)
# Louis (b = 12): 11/12/2012 (62%)
# Louis (b = 12): 11/13/2012 (64%)
# Louis (b = 12): 11/14/2012 (66%)
# Louis (b = 12): 11/15/2012 (68%)
# Louis (b = 12): 11/16/2012 (69%)
# Louis (b = 12): 11/17/2012 (71%)
# Louis (b = 12): 11/18/2012 (73%)
# Louis (b = 12): 11/19/2012 (75%)
# Louis (b = 12): 11/20/2012 (77%)
# Louis (b = 12): 11/21/2012 (79%)
# Louis (b = 12): 11/22/2012 (81%)
# Louis (b = 12): 11/23/2012 (83%)
# Louis (b = 12): 11/24/2012 (85%)
# Louis (b = 12): 11/25/2012 (88%)
# Louis (b = 12): 11/26/2012 (90%)
# Louis (b = 12): 11/28/2012 (93%)
# Louis (b = 12): 11/29/2012 (95%)
# Louis (b = 12): 11/30/2012 (97%)
# Louis (Ri capped, MJ98)
# Louis (Ri capped, MJ98): 9/24/2012 (2%)
# Louis (Ri capped, MJ98): 10/8/2012 (5%)
# Louis (Ri capped, MJ98): 10/9/2012 (7%)
# Louis (Ri capped, MJ98): 10/10/2012 (9%)
# Louis (Ri capped, MJ98): 10/11/2012 (10%)
# Louis (Ri capped, MJ98): 10/12/2012 (12%)
# Louis (Ri capped, MJ98): 10/13/2012 (13%)
# Louis (Ri capped, MJ98): 10/14/2012 (15%)
# Louis (Ri capped, MJ98): 10/15/2012 (16%)
# Louis (Ri capped, MJ98): 10/16/2012 (18%)
# Louis (Ri capped, MJ98): 10/17/2012 (20%)
# Louis (Ri capped, MJ98): 10/18/2012 (21%)
# Louis (Ri capped, MJ98): 10/19/2012 (23%)
# Louis (Ri capped, MJ98): 10/20/2012 (25%)
# Louis (Ri capped, MJ98): 10/21/2012 (27%)
# Louis (Ri capped, MJ98): 10/22/2012 (29%)
# Louis (Ri capped, MJ98): 10/23/2012 (30%)
# Louis (Ri capped, MJ98): 10/24/2012 (32%)
# Louis (Ri capped, MJ98): 10/27/2012 (34%)
# Louis (Ri capped, MJ98): 10/28/2012 (34%)
# Louis (Ri capped, MJ98): 10/29/2012 (35%)
# Louis (Ri capped, MJ98): 10/30/2012 (37%)
# Louis (Ri capped, MJ98): 10/31/2012 (39%)
# Louis (Ri capped, MJ98): 11/1/2012 (41%)
# Louis (Ri capped, MJ98): 11/2/2012 (43%)
# Louis (Ri capped, MJ98): 11/3/2012 (45%)
# Louis (Ri capped, MJ98): 11/4/2012 (47%)
# Louis (Ri capped, MJ98): 11/5/2012 (49%)
# Louis (Ri capped, MJ98): 11/6/2012 (51%)
# Louis (Ri capped, MJ98): 11/7/2012 (53%)
# Louis (Ri capped, MJ98): 11/8/2012 (55%)
# Louis (Ri capped, MJ98): 11/9/2012 (57%)
# Louis (Ri capped, MJ98): 11/10/2012 (59%)
# Louis (Ri capped, MJ98): 11/12/2012 (62%)
# Louis (Ri capped, MJ98): 11/13/2012 (64%)
# Louis (Ri capped, MJ98): 11/14/2012 (66%)
# Louis (Ri capped, MJ98): 11/15/2012 (68%)
# Louis (Ri capped, MJ98): 11/16/2012 (69%)
# MO (Holtslag/de Bruin): 10/13/2012 (13%)
# MO (Holtslag/de Bruin): 10/14/2012 (15%)
# MO (Holtslag/de Bruin): 10/15/2012 (16%)
# MO (Holtslag/de Bruin): 10/16/2012 (18%)
# MO (Holtslag/de Bruin): 10/17/2012 (20%)
# MO (Holtslag/de Bruin): 10/18/2012 (21%)
# MO (Holtslag/de Bruin): 10/19/2012 (23%)
# MO (Holtslag/de Bruin): 10/20/2012 (25%)
# MO (Holtslag/de Bruin): 10/21/2012 (27%)
# MO (Holtslag/de Bruin): 10/22/2012 (29%)
# MO (Holtslag/de Bruin): 10/23/2012 (30%)
# MO (Holtslag/de Bruin): 10/24/2012 (32%)
# MO (Holtslag/de Bruin): 10/27/2012 (34%)
# MO (Holtslag/de Bruin): 10/28/2012 (34%)
# MO (Holtslag/de Bruin): 10/29/2012 (35%)
# MO (Holtslag/de Bruin): 10/30/2012 (37%)
# MO (Holtslag/de Bruin): 10/31/2012 (39%)
# MO (Holtslag/de Bruin): 11/1/2012 (41%)
# MO (Holtslag/de Bruin): 11/2/2012 (43%)
# MO (Holtslag/de Bruin): 11/3/2012 (45%)
# MO (Holtslag/de Bruin): 11/4/2012 (47%)
# MO (Holtslag/de Bruin): 11/5/2012 (49%)
# MO (Holtslag/de Bruin): 11/6/2012 (51%)
# MO (Holtslag/de Bruin): 11/7/2012 (53%)
# MO (Holtslag/de Bruin): 11/8/2012 (55%)
# MO (Holtslag/de Bruin): 11/9/2012 (57%)
# MO (Holtslag/de Bruin): 11/10/2012 (59%)
# MO (Holtslag/de Bruin): 11/12/2012 (62%)
# MO (Holtslag/de Bruin): 11/13/2012 (64%)
# MO (Holtslag/de Bruin): 11/14/2012 (66%)
# MO (Holtslag/de Bruin): 11/15/2012 (68%)
# MO (Holtslag/de Bruin): 11/16/2012 (69%)
# MO (Holtslag/de Bruin): 11/17/2012 (71%)
# MO (Holtslag/de Bruin): 11/18/2012 (73%)
# MO (Holtslag/de Bruin): 11/19/2012 (75%)
# MO (Holtslag/de Bruin): 11/20/2012 (77%)
# MO (Holtslag/de Bruin): 11/21/2012 (79%)
# MO (Holtslag/de Bruin): 11/22/2012 (81%)
# MO (Holtslag/de Bruin): 11/23/2012 (83%)
# MO (Holtslag/de Bruin): 11/24/2012 (85%)
# MO (Holtslag/de Bruin): 11/25/2012 (88%)
# MO (Holtslag/de Bruin): 11/26/2012 (90%)
# MO (Holtslag/de Bruin): 11/28/2012 (93%)
# MO (Holtslag/de Bruin): 11/29/2012 (95%)
# MO (Holtslag/de Bruin): 11/30/2012 (97%)
# MO (Holtslag/de Bruin - capped)
# MO (Holtslag/de Bruin - capped): 9/24/2012 (2%)
# MO (Holtslag/de Bruin - capped): 10/8/2012 (5%)
# MO (Holtslag/de Bruin - capped): 10/9/2012 (7%)
# MO (Holtslag/de Bruin - capped): 10/10/2012 (9%)
# MO (Holtslag/de Bruin - capped): 10/11/2012 (10%)
# MO (Holtslag/de Bruin - capped): 10/12/2012 (12%)
# MO (Holtslag/de Bruin - capped): 10/13/2012 (13%)
# MO (Holtslag/de Bruin - capped): 10/14/2012 (15%)
# MO (Holtslag/de Bruin - capped): 10/15/2012 (16%)
# MO (Holtslag/de Bruin - capped): 10/16/2012 (18%)
# MO (Holtslag/de Bruin - capped): 10/17/2012 (20%)
# MO (Holtslag/de Bruin - capped): 10/18/2012 (21%)
# MO (Holtslag/de Bruin - capped): 10/19/2012 (23%)
# MO (Holtslag/de Bruin - capped): 10/20/2012 (25%)
# MO (Holtslag/de Bruin - capped): 10/21/2012 (27%)
# MO (Holtslag/de Bruin - capped): 10/22/2012 (29%)
# MO (Holtslag/de Bruin - capped): 10/23/2012 (30%)
# MO (Holtslag/de Bruin - capped): 10/24/2012 (32%)
# MO (Holtslag/de Bruin - capped): 10/27/2012 (34%)
# MO (Holtslag/de Bruin - capped): 10/28/2012 (34%)
# MO (Holtslag/de Bruin - capped): 10/29/2012 (35%)
# MO (Holtslag/de Bruin - capped): 10/30/2012 (37%)
# MO (Holtslag/de Bruin - capped): 10/31/2012 (39%)
# MO (Holtslag/de Bruin - capped): 11/1/2012 (41%)
# MO (Holtslag/de Bruin - capped): 11/2/2012 (43%)
# MO (Holtslag/de Bruin - capped): 11/3/2012 (45%)
# MO (Holtslag/de Bruin - capped): 11/4/2012 (47%)
# MO (Holtslag/de Bruin - capped): 11/5/2012 (49%)
# MO (Holtslag/de Bruin - capped): 11/6/2012 (51%)
# MO (Holtslag/de Bruin - capped): 11/7/2012 (53%)
# MO (Holtslag/de Bruin - capped): 11/8/2012 (55%)
# MO (Holtslag/de Bruin - capped): 11/9/2012 (57%)
# MO (Holtslag/de Bruin - capped): 11/10/2012 (59%)
# MO (Holtslag/de Bruin - capped): 11/12/2012 (62%)
# MO (Holtslag/de Bruin - capped): 11/13/2012 (64%)
# MO (Holtslag/de Bruin - capped): 11/14/2012 (66%)
# MO (Holtslag/de Bruin - capped): 11/15/2012 (68%)
# MO (Holtslag/de Bruin - capped): 11/16/2012 (69%)
# MO (Holtslag/de Bruin - capped): 11/17/2012 (71%)
# MO (Holtslag/de Bruin - capped): 11/18/2012 (73%)
# MO (Holtslag/de Bruin - capped): 11/19/2012 (75%)
# MO (Holtslag/de Bruin - capped): 11/20/2012 (77%)
# MO (Holtslag/de Bruin - capped): 11/21/2012 (79%)
# MO (Holtslag/de Bruin - capped): 11/22/2012 (81%)
# MO (Holtslag/de Bruin - capped): 11/23/2012 (83%)
# MO (Holtslag/de Bruin - capped): 11/24/2012 (85%)
# MO (Holtslag/de Bruin - capped): 11/25/2012 (88%)
# MO (Holtslag/de Bruin - capped): 11/26/2012 (90%)
# MO (Holtslag/de Bruin - capped): 11/28/2012 (93%)
# MO (Holtslag/de Bruin - capped): 11/29/2012 (95%)
# MO (Holtslag/de Bruin - capped): 11/30/2012 (97%)
# MO (Beljaars/Holtslag)
# MO (Beljaars/Holtslag): 9/24/2012 (2%)
# MO (Beljaars/Holtslag): 10/8/2012 (5%)
# MO (Beljaars/Holtslag): 10/9/2012 (7%)
# MO (Beljaars/Holtslag): 10/10/2012 (9%)
# MO (Beljaars/Holtslag): 10/11/2012 (10%)
# MO (Beljaars/Holtslag): 10/12/2012 (12%)
# MO (Cheng/Brutsaert): 10/22/2012 (29%)
# MO (Cheng/Brutsaert): 10/23/2012 (30%)
# MO (Cheng/Brutsaert): 10/24/2012 (32%)
# MO (Cheng/Brutsaert): 10/27/2012 (34%)
# MO (Cheng/Brutsaert): 10/28/2012 (34%)
# MO (Cheng/Brutsaert): 10/29/2012 (35%)
# MO (Cheng/Brutsaert): 10/30/2012 (37%)
# MO (Cheng/Brutsaert): 10/31/2012 (39%)
# MO (Cheng/Brutsaert): 11/1/2012 (41%)
# MO (Cheng/Brutsaert): 11/2/2012 (43%)
# MO (Cheng/Brutsaert): 11/3/2012 (45%)
# MO (Cheng/Brutsaert): 11/4/2012 (47%)
# MO (Cheng/Brutsaert): 11/5/2012 (49%)
# MO (Cheng/Brutsaert): 11/6/2012 (51%)
# MO (Cheng/Brutsaert): 11/7/2012 (53%)
# MO (Cheng/Brutsaert): 11/8/2012 (55%)
# MO (Cheng/Brutsaert): 11/9/2012 (57%)
# MO (Cheng/Brutsaert): 11/10/2012 (59%)
# MO (Cheng/Brutsaert): 11/12/2012 (62%)
# MO (Cheng/Brutsaert): 11/13/2012 (64%)
# MO (Cheng/Brutsaert): 11/14/2012 (66%)
# MO (Cheng/Brutsaert): 11/15/2012 (68%)
# MO (Cheng/Brutsaert): 11/16/2012 (69%)
# MO (Cheng/Brutsaert): 11/17/2012 (71%)
# MO (Cheng/Brutsaert): 11/18/2012 (73%)
# MO (Cheng/Brutsaert): 11/19/2012 (75%)
# MO (Cheng/Brutsaert): 11/20/2012 (77%)
# MO (Cheng/Brutsaert): 11/21/2012 (79%)
# MO (Cheng/Brutsaert): 11/22/2012 (81%)
# MO (Cheng/Brutsaert): 11/23/2012 (83%)
# MO (Cheng/Brutsaert): 11/24/2012 (85%)
# MO (Cheng/Brutsaert): 11/25/2012 (88%)
# MO (Cheng/Brutsaert): 11/26/2012 (90%)
# MO (Cheng/Brutsaert): 11/28/2012 (93%)
# MO (Cheng/Brutsaert): 11/29/2012 (95%)
# MO (Cheng/Brutsaert): 11/30/2012 (97%)

# %%
########
# Sensible
os.chdir(dir_print)
fig, axes = plt.subplots(2, 6, sharey=True, figsize=(15, 5))
Ri = Mtower['RiBulk_2m'][ind_2m]
axes = axes.flatten()
Qmax = 100
Qmin = -50
RiMax = 1.
RiMin = -0.1

for n, stab in enumerate(stab_titles):
    d = out_titles[stab]
    ax = axes[n]
    ax.plot(Ri, sensible_2m[d], '.')
    ax.plot([RiMin, RiMax], [0, 0], 'k--')
    ax.set_xlim(RiMin, RiMax)
    ax.set_ylim(Qmin, Qmax)
    ax.set_xlabel('Ri #')
    ax.set_title(d)

ax = axes[0]
ax.set_ylabel('$Q_h$ (Wm$^{-2}$)')

ax = axes[-1]
# ax.plot(Ri, Mtower[''.SensFlux[ind], '.')
ax.plot([RiMin, RiMax], [0, 0], 'k--')
ax.set_ylim(Qmin, Qmax)
ax.set_xlim(RiMin, RiMax)
ax.set_xlabel('Ri #')
ax.set_title('Observations')

fig.autofmt_xdate()
# fig.savefig('ATMS547.OfflineTurb.SNQ_wind2ms.Sensible_Ri.pdf')
